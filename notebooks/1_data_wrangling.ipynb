# %% [markdown]
# # California K-12 Public Schools
# ## Predicting Test Performance

# %% [markdown]
#    <img src='../images/education_image.jpg' width="900">
#
#    **Credit:**  [wsimag](https://wsimag.com/culture/60264-education-in-venezuela-the-americas-and-the-world)

# %%
# Load relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import warnings

sns.set(style='ticks')

warnings.filterwarnings("ignore")  # Suppress all warnings

# %% [markdown]
# <!-- ## Business Context
# Research shows that high-poverty areas disproportionally educate children of color. The chances of ending up in a high-poverty or high-minority school are highly determined by a student’s race/ethnicity and social class. For instance, African American and Hispanic students—even if they are not poor—are much more likely than White or Asian students to be in high-poverty schools.
#
# There is a growing body of evidence that shows increased investment on education returns better outcomes and that the positive effects are even greater among low-income students. On the other hand, it costs more to educate low-income students and provide them with a robust education capable of overcoming their initial disadvantages.
#
#
# ### Goals
# 1. Understand the current demographics of wealthy to high-poverty schools across the state of California.
# 2. Identify how much funding is available per pupil in wealthy vs high-poverty areas.
# 3. Learn what factors are most correlated with student performance.
#
#
# #### Predictive modeling
# What's the percentage of students meeting the standards?
#  -->
#
# # DATA WRANGLING
#
# The process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics.
#
# - Extracting relevant data. Let's start looking at the datasets!

# %% [markdown]
# ## 1. Assessment Data
#
# - It contains assessment data for the Smarter Balance Summative Assessment (2018-2019) for the state of California.
#
# - Legend types can be found here: https://caaspp-elpac.cde.ca.gov/caaspp/research_fixfileformat19
# - More information about assesment set up: https://www.cde.ca.gov/ta/tg/ca/sbsummativefaq.asp
# - Research file info: https://caaspp-elpac.cde.ca.gov/caaspp/ResearchFileList?ps=true&lstTestYear=2019&lstTestType=B&lstCounty=00&lstDistrict=00000&lstSchool=0000000

# %%
# load datafile
df_all = pd.read_csv('large_data/sb_ca2019_all_csv_v4.txt')

# %%
# create dataset containing district level data
df_district = df_all[df_all['School Code'] == 0000000]

# %%
# create dataset containing school level data
df_school = df_all.drop(df_all[df_all['School Code'] == 0].index)
df_school
# Out:
#          County Code  District Code  School Code  Filler  Test Year  \
# 1888               1          10017       112607     NaN       2019
# 1889               1          10017       112607     NaN       2019
# 1890               1          10017       112607     NaN       2019
# 1891               1          10017       112607     NaN       2019
# 1892               1          10017       112607     NaN       2019
# ...              ...            ...          ...     ...        ...
# 3576486           58          72769      5838305     NaN       2019
# 3576487           58          72769      5838305     NaN       2019
# 3576488           58          72769      5838305     NaN       2019
# 3576489           58          72769      5838305     NaN       2019
# 3576490           58          72769      5838305     NaN       2019
#
#          Subgroup ID Test Type Total Tested At Entity Level  \
# 1888               1         B                           85
# 1889               3         B                           42
# 1890               4         B                           43
# 1891               6         B                           79
# 1892               7         B                            *
# ...              ...       ...                          ...
# 3576486          222         B                            *
# 3576487          223         B                            *
# 3576488          224         B                           19
# 3576489          226         B                           54
# 3576490          227         B                            9
#
#         Total Tested with Scores  Grade  ...  \
# 1888                          84     11  ...
# 1889                          42     11  ...
# 1890                          42     11  ...
# 1891                          78     11  ...
# 1892                           *     11  ...
# ...                          ...    ...  ...
# 3576486                        *     13  ...
# 3576487                        *     13  ...
# 3576488                       19     13  ...
# 3576489                       54     13  ...
# 3576490                        9     13  ...
#
#          Area 1 Percentage Below Standard Area 2 Percentage Above Standard  \
# 1888                                37.35                            12.20
# 1889                                35.71                            14.29
# 1890                                39.02                            10.00
# 1891                                33.77                            13.16
# 1892                                    *                                *
# ...                                   ...                              ...
# 3576486                                 *                                *
# 3576487                                 *                                *
# 3576488                             57.89                             0.00
# 3576489                             55.56                            16.67
# 3576490                                 *                                *
#
#         Area 2 Percentage Near Standard Area 2 Percentage Below Standard  \
# 1888                              60.98                            26.83
# 1889                              50.00                            35.71
# 1890                              72.50                            17.50
# 1891                              63.16                            23.68
# 1892                                  *                                *
# ...                                 ...                              ...
# 3576486                               *                                *
# 3576487                               *                                *
# 3576488                           63.16                            36.84
# 3576489                           44.44                            38.89
# 3576490                               *                                *
#
#         Area 3 Percentage Above Standard Area 3 Percentage Near Standard  \
# 1888                                7.23                           71.08
# 1889                                7.14                           76.19
# 1890                                7.32                           65.85
# 1891                                7.79                           71.43
# 1892                                   *                               *
# ...                                  ...                             ...
# 3576486                                *                               *
# 3576487                                *                               *
# 3576488                             5.26                           57.89
# 3576489                            14.81                           57.41
# 3576490                                *                               *
#
#         Area 3 Percentage Below Standard Area 4 Percentage Above Standard  \
# 1888                               21.69                            13.25
# 1889                               16.67                             9.52
# 1890                               26.83                            17.07
# 1891                               20.78                            14.29
# 1892                                   *                                *
# ...                                  ...                              ...
# 3576486                                *                                *
# 3576487                                *                                *
# 3576488                            36.84                             0.00
# 3576489                            27.78                             0.00
# 3576490                                *                                *
#
#         Area 4 Percentage Near Standard Area 4 Percentage Below Standard
# 1888                              61.45                            25.30
# 1889                              64.29                            26.19
# 1890                              58.54                            24.39
# 1891                              63.64                            22.08
# 1892                                  *                                *
# ...                                 ...                              ...
# 3576486                               *                                *
# 3576487                               *                                *
# 3576488                            0.00                             0.00
# 3576489                            0.00                             0.00
# 3576490                               *                                *
#
# [3013079 rows x 32 columns]

# %%
# check columns names
df_school.columns
# Out:
# Index(['County Code', 'District Code', 'School Code', 'Filler', 'Test Year',
#        'Subgroup ID', 'Test Type', 'Total Tested At Entity Level',
#        'Total Tested with Scores', 'Grade', 'Test Id',
#        'CAASPP Reported Enrollment', 'Students Tested', 'Mean Scale Score',
#        'Percentage Standard Exceeded', 'Percentage Standard Met',
#        'Percentage Standard Met and Above', 'Percentage Standard Nearly Met',
#        'Percentage Standard Not Met', 'Students with Scores',
#        'Area 1 Percentage Above Standard', 'Area 1 Percentage Near Standard',
#        'Area 1 Percentage Below Standard', 'Area 2 Percentage Above Standard',
#        'Area 2 Percentage Near Standard', 'Area 2 Percentage Below Standard',
#        'Area 3 Percentage Above Standard', 'Area 3 Percentage Near Standard',
#        'Area 3 Percentage Below Standard', 'Area 4 Percentage Above Standard',
#        'Area 4 Percentage Near Standard', 'Area 4 Percentage Below Standard'],
#       dtype='object')

# %%
# check data type
df_school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3013079 entries, 1888 to 3576490
# Data columns (total 32 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   County Code                        int64
#  1   District Code                      int64
#  2   School Code                        int64
#  3   Filler                             float64
#  4   Test Year                          int64
#  5   Subgroup ID                        int64
#  6   Test Type                          object
#  7   Total Tested At Entity Level       object
#  8   Total Tested with Scores           object
#  9   Grade                              int64
#  10  Test Id                            int64
#  11  CAASPP Reported Enrollment         object
#  12  Students Tested                    object
#  13  Mean Scale Score                   object
#  14  Percentage Standard Exceeded       object
#  15  Percentage Standard Met            object
#  16  Percentage Standard Met and Above  object
#  17  Percentage Standard Nearly Met     object
#  18  Percentage Standard Not Met        object
#  19  Students with Scores               object
#  20  Area 1 Percentage Above Standard   object
#  21  Area 1 Percentage Near Standard    object
#  22  Area 1 Percentage Below Standard   object
#  23  Area 2 Percentage Above Standard   object
#  24  Area 2 Percentage Near Standard    object
#  25  Area 2 Percentage Below Standard   object
#  26  Area 3 Percentage Above Standard   object
#  27  Area 3 Percentage Near Standard    object
#  28  Area 3 Percentage Below Standard   object
#  29  Area 4 Percentage Above Standard   object
#  30  Area 4 Percentage Near Standard    object
#  31  Area 4 Percentage Below Standard   object
# dtypes: float64(1), int64(7), object(24)
# memory usage: 758.6+ MB

# %%
# Check for missing data
df_school.isnull().sum()
# Out:
# County Code                                0
# District Code                              0
# School Code                                0
# Filler                               3013079
# Test Year                                  0
# Subgroup ID                                0
# Test Type                                  0
# Total Tested At Entity Level               0
# Total Tested with Scores                   0
# Grade                                      0
# Test Id                                    0
# CAASPP Reported Enrollment                 0
# Students Tested                            0
# Mean Scale Score                      797631
# Percentage Standard Exceeded               0
# Percentage Standard Met                    0
# Percentage Standard Met and Above          0
# Percentage Standard Nearly Met             0
# Percentage Standard Not Met                0
# Students with Scores                       0
# Area 1 Percentage Above Standard           0
# Area 1 Percentage Near Standard            0
# Area 1 Percentage Below Standard           0
# Area 2 Percentage Above Standard           0
# Area 2 Percentage Near Standard            0
# Area 2 Percentage Below Standard           0
# Area 3 Percentage Above Standard           0
# Area 3 Percentage Near Standard            0
# Area 3 Percentage Below Standard           0
# Area 4 Percentage Above Standard           0
# Area 4 Percentage Near Standard            0
# Area 4 Percentage Below Standard           0
# dtype: int64

# %% [markdown]
# - Verifying number of rows where Subgroup Id == 1:
#     - Summary of all students per school

# %%
# Number of rows where subgroup ID == 1
df_school[df_school['Subgroup ID'] == 1].count()
# Out:
# County Code                          87324
# District Code                        87324
# School Code                          87324
# Filler                                   0
# Test Year                            87324
# Subgroup ID                          87324
# Test Type                            87324
# Total Tested At Entity Level         87324
# Total Tested with Scores             87324
# Grade                                87324
# Test Id                              87324
# CAASPP Reported Enrollment           87324
# Students Tested                      87324
# Mean Scale Score                     66727
# Percentage Standard Exceeded         87324
# Percentage Standard Met              87324
# Percentage Standard Met and Above    87324
# Percentage Standard Nearly Met       87324
# Percentage Standard Not Met          87324
# Students with Scores                 87324
# Area 1 Percentage Above Standard     87324
# Area 1 Percentage Near Standard      87324
# Area 1 Percentage Below Standard     87324
# Area 2 Percentage Above Standard     87324
# Area 2 Percentage Near Standard      87324
# Area 2 Percentage Below Standard     87324
# Area 3 Percentage Above Standard     87324
# Area 3 Percentage Near Standard      87324
# Area 3 Percentage Below Standard     87324
# Area 4 Percentage Above Standard     87324
# Area 4 Percentage Near Standard      87324
# Area 4 Percentage Below Standard     87324
# dtype: int64

# %%
# Check number of unique schools
df_school['School Code'].nunique()
# Out:
# 10300

# %% [markdown]
# - There are 10,300 schools!

# %% [markdown]
# ## Creating two datasets for modeling
#
# - Language Arts & Literature: test_id == 1
#
#     - 10,299 rows
#
#
# - Mathematics: test_id == 2
#
#     - 10,298 rows

# %%
# Filter Grade == 13 summary of all grades per school
all_grades = df_school[df_school['Grade'] == 13]

# Filter Subgroup ID == 1 summary of all students
all_students = all_grades[all_grades['Subgroup ID'] == 1]

# %% [markdown]
# - Language Arts & Literature Dataset:

# %%
# Create df_test1 language arts & literature 
df_test1 = all_students[all_students['Test Id'] == 1]

# drop columns that won't be used
df_language = df_test1.drop(columns = ['Filler', 'Test Year', 'Test Type', 'District Code',
                             'Area 1 Percentage Above Standard', 'Area 1 Percentage Near Standard',
                             'Area 1 Percentage Below Standard', 'Area 2 Percentage Above Standard',
                             'Area 2 Percentage Near Standard', 'Area 2 Percentage Below Standard',
                             'Area 3 Percentage Above Standard', 'Area 3 Percentage Near Standard',
                             'Area 3 Percentage Below Standard', 'Area 4 Percentage Above Standard',
                             'Area 4 Percentage Near Standard', 'Area 4 Percentage Below Standard', 
                             'Total Tested At Entity Level', 'Total Tested with Scores', 'Grade',
                             'Test Id', 'Students Tested'])

#df_language

# %% [markdown]
# - Mathematics Dataset:

# %%
# Create df_test2 mathematics
df_test2 = all_students[all_students['Test Id'] == 2]

# drop columns with redundant information
df_math = df_test2.drop(columns = ['Filler', 'Test Year', 'Test Type', 'District Code',
                             'Area 1 Percentage Above Standard', 'Area 1 Percentage Near Standard',
                             'Area 1 Percentage Below Standard', 'Area 2 Percentage Above Standard',
                             'Area 2 Percentage Near Standard', 'Area 2 Percentage Below Standard',
                             'Area 3 Percentage Above Standard', 'Area 3 Percentage Near Standard',
                             'Area 3 Percentage Below Standard', 'Area 4 Percentage Above Standard',
                             'Area 4 Percentage Near Standard', 'Area 4 Percentage Below Standard',
                             'Total Tested At Entity Level', 'Total Tested with Scores', 'Grade',
                             'Test Id', 'Students Tested'])
#df_math

# %% [markdown]
# -------------

# %% [markdown]
# ### Reorganizing Subgroup ID
#
# The assessment dataset contains a lot of demographic information in the subgroup ID column. Need to reorganize the dataset in order to have one variable per column and one observation per row. Also, neet to filter only the demographic information of interest.
#
# #### Before merging:
# - Filter variables of interest;
# - Rearrange the data to have:
#     - one feature per column;
#     - one observation per row;
#
# This dataset representes the Smater Balanced Assessments for English Language Arts/Literacy and Mathematics (SB). Test ID 1 and 2. More info about the test can be found here: https://www.caaspp.org/administration/about/testing/index.html

# %% [markdown]
# ## 1. a. Subgroup ID
#
# In the legend below, Demographic Id and Demographic Id Num are represented in the dataset as Subgroup ID.

# %%
legend = pd.read_csv('data/Subgroups.txt')
legend
# Out:
#     Demographic ID  Demographic ID Num  \
# 0                1                   1
# 1                3                   3
# 2                4                   4
# 3                6                   6
# 4                7                   7
# 5                8                   8
# 6               28                  28
# 7               31                  31
# 8               50                  50
# 9               51                  51
# 10              52                  52
# 11              53                  53
# 12              74                  74
# 13              75                  75
# 14              76                  76
# 15              77                  77
# 16              78                  78
# 17              79                  79
# 18              80                  80
# 19              90                  90
# 20              91                  91
# 21              92                  92
# 22              93                  93
# 23              94                  94
# 24              99                  99
# 25             111                 111
# 26             120                 120
# 27             121                 121
# 28             128                 128
# 29             142                 142
# 30             144                 144
# 31             160                 160
# 32             170                 170
# 33             180                 180
# 34             190                 190
# 35             200                 200
# 36             201                 201
# 37             202                 202
# 38             203                 203
# 39             204                 204
# 40             205                 205
# 41             206                 206
# 42             207                 207
# 43             220                 220
# 44             221                 221
# 45             222                 222
# 46             223                 223
# 47             224                 224
# 48             225                 225
# 49             226                 226
# 50             227                 227
#
#                                      Demographic Name  \
# 0                                        All Students
# 1                                                Male
# 2                                              Female
# 3          Fluent English proficient and English only
# 4            Initial fluent English proficient (IFEP)
# 5       Reclassified fluent English proficient (RFEP)
# 6                                   Migrant education
# 7                          Economically disadvantaged
# 8                                            Military
# 9                                        Not Military
# 10                                           Homeless
# 11                                       Not Homeless
# 12                          Black or African American
# 13                   American Indian or Alaska Native
# 14                                              Asian
# 15                                           Filipino
# 16                                 Hispanic or Latino
# 17                Native Hawaiian or Pacific Islander
# 18                                              White
# 19                         Not a high school graduate
# 20                               High school graduate
# 21                  Some college (includes AA degree)
# 22                                   College graduate
# 23                      Graduate school/Post graduate
# 24               Students with no reported disability
# 25                     Not economically disadvantaged
# 26  English learners (ELs) enrolled in school in t...
# 27                                  Declined to state
# 28                           Students with disability
# 29  English learners enrolled in school in the U.S...
# 30                                  Two or more races
# 31                                    English learner
# 32                                           Ever-ELs
# 33                                       English only
# 34                             To be determined (TBD)
# 35                          Black or African American
# 36                   American Indian or Alaska Native
# 37                                              Asian
# 38                                           Filipino
# 39                                 Hispanic or Latino
# 40                Native Hawaiian or Pacific Islander
# 41                                              White
# 42                                  Two or more races
# 43                          Black or African American
# 44                   American Indian or Alaska Native
# 45                                              Asian
# 46                                           Filipino
# 47                                 Hispanic or Latino
# 48                Native Hawaiian or Pacific Islander
# 49                                              White
# 50                                  Two or more races
#
#                                    Student Group
# 0                                   All Students
# 1                                         Gender
# 2                                         Gender
# 3                       English-Language Fluency
# 4                       English-Language Fluency
# 5                       English-Language Fluency
# 6                                        Migrant
# 7                                Economic Status
# 8                                Military Status
# 9                                Military Status
# 10                               Homeless Status
# 11                               Homeless Status
# 12                                     Ethnicity
# 13                                     Ethnicity
# 14                                     Ethnicity
# 15                                     Ethnicity
# 16                                     Ethnicity
# 17                                     Ethnicity
# 18                                     Ethnicity
# 19                              Parent Education
# 20                              Parent Education
# 21                              Parent Education
# 22                              Parent Education
# 23                              Parent Education
# 24                             Disability Status
# 25                               Economic Status
# 26                      English-Language Fluency
# 27                              Parent Education
# 28                             Disability Status
# 29                      English-Language Fluency
# 30                                     Ethnicity
# 31                      English-Language Fluency
# 32                      English-Language Fluency
# 33                      English-Language Fluency
# 34                      English-Language Fluency
# 35      Ethnicity for Economically Disadvantaged
# 36      Ethnicity for Economically Disadvantaged
# 37      Ethnicity for Economically Disadvantaged
# 38      Ethnicity for Economically Disadvantaged
# 39      Ethnicity for Economically Disadvantaged
# 40      Ethnicity for Economically Disadvantaged
# 41      Ethnicity for Economically Disadvantaged
# 42      Ethnicity for Economically Disadvantaged
# 43  Ethnicity for Not Economically Disadvantaged
# 44  Ethnicity for Not Economically Disadvantaged
# 45  Ethnicity for Not Economically Disadvantaged
# 46  Ethnicity for Not Economically Disadvantaged
# 47  Ethnicity for Not Economically Disadvantaged
# 48  Ethnicity for Not Economically Disadvantaged
# 49  Ethnicity for Not Economically Disadvantaged
# 50  Ethnicity for Not Economically Disadvantaged

# %% [markdown]
# ### Next:
# 1. Transform demographic information contained in subgroup id column into one variable per column.
#     - Drop redundant columns;
#     - Remap each variable of interest to its own column;
#     - Value is number of students fitting each category.

# %%
# drop columns that won't be used
all_grades = all_grades.drop(columns = ['Filler', 'Test Year', 'Test Type', 'District Code', 'County Code',
                             'Area 1 Percentage Above Standard', 'Area 1 Percentage Near Standard',
                             'Area 1 Percentage Below Standard', 'Area 2 Percentage Above Standard',
                             'Area 2 Percentage Near Standard', 'Area 2 Percentage Below Standard',
                             'Area 3 Percentage Above Standard', 'Area 3 Percentage Near Standard',
                             'Area 3 Percentage Below Standard', 'Area 4 Percentage Above Standard',
                             'Area 4 Percentage Near Standard', 'Area 4 Percentage Below Standard',
                             'Mean Scale Score', 'Percentage Standard Exceeded', 'Percentage Standard Met',
                             'Percentage Standard Met and Above', 'Percentage Standard Nearly Met',
                             'Percentage Standard Not Met', 'Students with Scores', 'Total Tested At Entity Level',
                             'Total Tested with Scores', 'Students Tested', 'Grade'])

# %% [markdown]
# ### Reshape the data
#
# **Language Arts & Literature Dataset:**

# %%
# Filter subgroup_id and test_id, rename column and merge into main df
def merge_column(subgroup_id, name):
    df = all_grades[(all_grades['Subgroup ID'] == subgroup_id) & (all_grades['Test Id'] == 1)]
    df = df.drop(columns=['Test Id', 'Subgroup ID'])
    df = df.rename({'CAASPP Reported Enrollment': name}, axis=1)
    global df_language
    df_language = df_language.merge(df, how='left', on='School Code')

# %%
# Define dictionary to merge columns
dict = {3:'Male', 4:'Female', 6:'Fluent English', 160:'English Learner', 170:'Ever-Els', 28:'Migrant', 50:'Military', 51:'Non Military', 52:'Homeless', 53:'Non Homeless', 31:'Disadvantaged',
       111:'Not Disadvantaged', 74:'Black', 75:'Native American', 76:'Asian', 78:'Hispanic', 79:'Pacific Islander',
       80:'White', 144:'Two/More Races', 90:'< High School', 91:'High School Grad', 92:'Some College', 
       93:'College Grad', 94:'Graduate School'}

# %%
# Loop through dict to define label and merge column to language_df
for subgroup_id, column_name in dict.items():
    merge_column(subgroup_id, column_name)

# %%
# Check the result
df_language
# Out:
#        County Code  School Code  Subgroup ID CAASPP Reported Enrollment  \
# 0                1       112607            1                         90
# 1                1       123968            1                        142
# 2                1       124172            1                        239
# 3                1       125567            1                        201
# 4                1       130401            1                          *
# ...            ...          ...          ...                        ...
# 10294           58      6056816            1                        608
# 10295           58      6056832            1                        146
# 10296           58      6056840            1                         74
# 10297           58      6118806            1                         57
# 10298           58      5838305            1                        217
#
#       Mean Scale Score Percentage Standard Exceeded Percentage Standard Met  \
# 0                  NaN                         7.14                   27.38
# 1                  NaN                         7.09                   18.11
# 2                  NaN                        71.12                   22.41
# 3                  NaN                        28.13                   17.71
# 4                  NaN                            *                       *
# ...                ...                          ...                     ...
# 10294              NaN                        13.95                   37.41
# 10295              NaN                        25.76                   25.76
# 10296              NaN                        31.08                   22.97
# 10297              NaN                        23.53                   41.18
# 10298              NaN                        19.34                   31.13
#
#       Percentage Standard Met and Above Percentage Standard Nearly Met  \
# 0                                 34.52                          36.90
# 1                                 25.20                          29.92
# 2                                 93.53                           4.31
# 3                                 45.83                          18.75
# 4                                     *                              *
# ...                                 ...                            ...
# 10294                             51.36                          24.32
# 10295                             51.52                          27.27
# 10296                             54.05                          18.92
# 10297                             64.71                          21.57
# 10298                             50.47                          26.42
#
#       Percentage Standard Not Met  ... Asian Hispanic Pacific Islander White  \
# 0                           28.57  ...     *       46                *     4
# 1                           44.88  ...    10       82              NaN     5
# 2                            2.16  ...   111        9              NaN    18
# 3                           35.42  ...    14       50              NaN    64
# 4                               *  ...   NaN        *                *     *
# ...                           ...  ...   ...      ...              ...   ...
# 10294                       24.32  ...    15      166                5   314
# 10295                       21.21  ...   NaN       26                *    83
# 10296                       27.03  ...     *       27              NaN    40
# 10297                       13.73  ...   NaN       15                *    29
# 10298                       23.11  ...     6       65                *    93
#
#       Two/More Races < High School High School Grad Some College College Grad  \
# 0                  *            23               20           19           11
# 1                  4            28               39           34           14
# 2                 94           NaN                *            7           58
# 3                 27             *               17           39           59
# 4                NaN             *                *            *            *
# ...              ...           ...              ...          ...          ...
# 10294             61            32               97          255          156
# 10295             14           NaN               10           64           44
# 10296              4            10               15           30           13
# 10297              8           NaN                *           18           23
# 10298             32            12               32           69           50
#
#       Graduate School
# 0                   *
# 1                  13
# 2                 164
# 3                  76
# 4                   *
# ...               ...
# 10294              57
# 10295              26
# 10296               6
# 10297              15
# 10298              24
#
# [10299 rows x 35 columns]

# %% [markdown]
# **Mathematics Dataset:**

# %%
# Filter subgroup_id and test_id, rename column and merge into main df
def merge_column(subgroup_id, name):
    df = all_grades[(all_grades['Subgroup ID'] == subgroup_id) & (all_grades['Test Id'] == 2)]
    df = df.drop(columns=['Test Id', 'Subgroup ID'])
    df = df.rename({'CAASPP Reported Enrollment': name}, axis=1)
    global df_math
    df_math = df_math.merge(df, how='left', on='School Code')

# %%
# Define dictionary to merge columns
dict = {3:'Male', 4:'Female', 6:'Fluent English', 160:'English Learner', 170:'Ever-Els', 28:'Migrant', 50:'Military', 51:'Non Military', 52:'Homeless', 53:'Non Homeless', 31:'Disadvantaged',
       111:'Not Disadvantaged', 74:'Black', 75:'Native American', 76:'Asian', 78:'Hispanic', 79:'Pacific Islander',
       80:'White', 144:'Two/More Races', 90:'< High School', 91:'High School Grad', 92:'Some College', 
       93:'College Grad', 94:'Graduate School'}

# %%
# Loop through dict to define label and merge column to math_df
for subgroup_id, column_name in dict.items():
    merge_column(subgroup_id, column_name)

# %%
# check the result
df_math
# Out:
#        County Code  School Code  Subgroup ID CAASPP Reported Enrollment  \
# 0                1       112607            1                         90
# 1                1       123968            1                        142
# 2                1       124172            1                        239
# 3                1       125567            1                        201
# 4                1       130401            1                         34
# ...            ...          ...          ...                        ...
# 10293           58      6056816            1                        608
# 10294           58      6056832            1                        146
# 10295           58      6056840            1                         74
# 10296           58      6118806            1                         57
# 10297           58      5838305            1                        217
#
#       Mean Scale Score Percentage Standard Exceeded Percentage Standard Met  \
# 0                  NaN                         3.57                    7.14
# 1                  NaN                         6.67                   11.11
# 2                  NaN                        74.57                   19.40
# 3                  NaN                        17.10                   18.65
# 4                  NaN                            *                       *
# ...                ...                          ...                     ...
# 10293              NaN                        13.78                   27.04
# 10294              NaN                         9.09                   24.24
# 10295              NaN                        12.16                   31.08
# 10296              NaN                        15.69                   35.29
# 10297              NaN                         4.72                   18.87
#
#       Percentage Standard Met and Above Percentage Standard Nearly Met  \
# 0                                 10.71                          16.67
# 1                                 17.78                          28.15
# 2                                 93.97                           5.17
# 3                                 35.75                          18.13
# 4                                     *                              *
# ...                                 ...                            ...
# 10293                             40.82                          32.48
# 10294                             33.33                          40.15
# 10295                             43.24                          27.03
# 10296                             50.98                          29.41
# 10297                             23.58                          31.13
#
#       Percentage Standard Not Met  ... Asian Hispanic Pacific Islander White  \
# 0                           72.62  ...     *       46                *     4
# 1                           54.07  ...    10       82              NaN     5
# 2                            0.86  ...   111        9              NaN    18
# 3                           46.11  ...    14       50              NaN    64
# 4                               *  ...   NaN        *                *     *
# ...                           ...  ...   ...      ...              ...   ...
# 10293                       26.70  ...    15      166                5   314
# 10294                       26.52  ...   NaN       26                *    83
# 10295                       29.73  ...     *       27              NaN    40
# 10296                       19.61  ...   NaN       15                *    29
# 10297                       45.28  ...     6       65                *    93
#
#       Two/More Races < High School High School Grad Some College College Grad  \
# 0                  *            23               20           19           11
# 1                  4            28               39           34           14
# 2                 94           NaN                *            7           58
# 3                 27             *               17           39           59
# 4                NaN             *                *            *            *
# ...              ...           ...              ...          ...          ...
# 10293             61            32               97          255          156
# 10294             14           NaN               10           64           44
# 10295              4            10               15           30           13
# 10296              8           NaN                *           18           23
# 10297             32            12               32           69           50
#
#       Graduate School
# 0                   *
# 1                  13
# 2                 164
# 3                  76
# 4                   *
# ...               ...
# 10293              57
# 10294              26
# 10295               6
# 10296              15
# 10297              24
#
# [10298 rows x 35 columns]

# %% [markdown]
# ---------

# %% [markdown]
# ## 1. b. Entities Data
#
# - It contains information such as school and district name, zip code and relevant codes to allow merge with the assessment data.
#
# Number of rows in this dataset is closely related to current information about number of schools and districts in the state of CA:
#
# - There are ~ 1,040 school districts in California.
#     - The entities_dist dataset contains 1,087 rows.
# - There are ~ 10,588 schools in California.
#     - The df_entities dataset contains 10,300 rows.

# %%
df_entities = pd.read_csv('data/sb_ca2019entities_csv.txt')

# %%
# create dataset containing entities data at district level
entities_dist = df_entities[df_entities['School Code'] == 0]

# create dataset containing entities data at school level 
df_entities = df_entities.drop(df_entities[df_entities['School Code'] == 0].index) # drop district level data

# drop columns with redundant information or not of use 
df_entities = df_entities.drop(columns = ['Filler', 'Test Year','Type Id', 'District Name', 'County Code'])

# %%
df_entities.sort_values(by=['School Name'])
# Out:
#       District Code  School Code  County Name  \
# 9734          66993       129882    Riverside
# 9009          66480      6027767       Orange
# 9069          66522      6028211       Orange
# 9444          73643      6085377       Orange
# 2685          69369      6046114  Santa Clara
# ...             ...          ...          ...
# 8056          75309       136531  Los Angeles
# 8060          75309       138297  Los Angeles
# 7996          73452       120600  Los Angeles
# 828           10397       120717  San Joaquin
# 7921          73437       137984  Los Angeles
#
#                             School Name Zip Code
# 9734    21st Century Learning Institute    92223
# 9009            A. E. Arnold Elementary    90630
# 9069              A. G. Cook Elementary    92844
# 9444                A. G. Currie Middle    92780
# 2685             A. J. Dorsa Elementary    95122
# ...                                 ...      ...
# 8056                       iLEAD Online    93510
# 8060                   iLead Agua Dulce    91390
# 7996  iQ Academy California-Los Angeles    93065
# 828                         one.Charter    95206
# 7921              �nimo Compton Charter    90061
#
# [10300 rows x 5 columns]

# %%
df_entities['School Name'].nunique()
# Out:
# 9042

# %%
df_entities['School Code'].nunique()
# Out:
# 10300

# %% [markdown]
# --------

# %% [markdown]
# ### Merge df_entities to df_language and df_math
#
# This merge adds school name and zipcode to df_language and df_math.
#
# **Language Arts & Literature Dataset**

# %%
# merge dfs on school code
df_language_merge = df_entities.merge(df_language, how='left', on='School Code')

# Check the result
df_language_merge.head()
# Out:
#    District Code  School Code County Name                 School Name  \
# 0          68056       114686   San Diego                   Ocean Air
# 1          68056      6038111   San Diego  Del Mar Heights Elementary
# 2          68056      6088983   San Diego    Del Mar Hills Elementary
# 3          68056      6110696   San Diego   Carmel Del Mar Elementary
# 4          68056      6115620   San Diego     Ashley Falls Elementary
#
#   Zip Code  County Code  Subgroup ID CAASPP Reported Enrollment  \
# 0    92130         37.0          1.0                        420
# 1    92014         37.0          1.0                        275
# 2    92014         37.0          1.0                        169
# 3    92130         37.0          1.0                        299
# 4    92130         37.0          1.0                        331
#
#   Mean Scale Score Percentage Standard Exceeded  ... Asian Hispanic  \
# 0              NaN                        71.19  ...   175       26
# 1              NaN                        69.23  ...    19       23
# 2              NaN                        61.35  ...    13       33
# 3              NaN                        68.03  ...    91       34
# 4              NaN                        51.85  ...   100       29
#
#   Pacific Islander White Two/More Races < High School High School Grad  \
# 0              NaN   188             24           NaN                *
# 1                *   203             25           NaN                *
# 2              NaN   105             17             *                4
# 3              NaN   148             21             *                *
# 4                *   171             15           NaN                *
#
#   Some College College Grad Graduate School
# 0            4           85             326
# 1            9           85             178
# 2           13           47              99
# 3           10           73             203
# 4           18           63             241
#
# [5 rows x 39 columns]

# %%
# Check the columns
df_language_merge.columns
# Out:
# Index(['District Code', 'School Code', 'County Name', 'School Name',
#        'Zip Code', 'County Code', 'Subgroup ID', 'CAASPP Reported Enrollment',
#        'Mean Scale Score', 'Percentage Standard Exceeded',
#        'Percentage Standard Met', 'Percentage Standard Met and Above',
#        'Percentage Standard Nearly Met', 'Percentage Standard Not Met',
#        'Students with Scores', 'Male', 'Female', 'Fluent English',
#        'English Learner', 'Ever-Els', 'Migrant', 'Military', 'Non Military',
#        'Homeless', 'Non Homeless', 'Disadvantaged', 'Not Disadvantaged',
#        'Black', 'Native American', 'Asian', 'Hispanic', 'Pacific Islander',
#        'White', 'Two/More Races', '< High School', 'High School Grad',
#        'Some College', 'College Grad', 'Graduate School'],
#       dtype='object')

# %% [markdown]
# **Mathematics Dataset**

# %%
# Merge
df_math_merge = df_entities.merge(df_math, how='left', on='School Code')

# Result
df_math_merge.head()
# Out:
#    District Code  School Code County Name                 School Name  \
# 0          68056       114686   San Diego                   Ocean Air
# 1          68056      6038111   San Diego  Del Mar Heights Elementary
# 2          68056      6088983   San Diego    Del Mar Hills Elementary
# 3          68056      6110696   San Diego   Carmel Del Mar Elementary
# 4          68056      6115620   San Diego     Ashley Falls Elementary
#
#   Zip Code  County Code  Subgroup ID CAASPP Reported Enrollment  \
# 0    92130         37.0          1.0                        420
# 1    92014         37.0          1.0                        275
# 2    92014         37.0          1.0                        169
# 3    92130         37.0          1.0                        299
# 4    92130         37.0          1.0                        331
#
#   Mean Scale Score Percentage Standard Exceeded  ... Asian Hispanic  \
# 0              NaN                        76.44  ...   175       26
# 1              NaN                        67.40  ...    19       23
# 2              NaN                        54.49  ...    13       33
# 3              NaN                        70.71  ...    91       34
# 4              NaN                        55.49  ...   100       29
#
#   Pacific Islander White Two/More Races < High School High School Grad  \
# 0              NaN   188             24           NaN                *
# 1                *   203             25           NaN                *
# 2              NaN   105             17             *                4
# 3              NaN   148             21             *                *
# 4                *   171             15           NaN                *
#
#   Some College College Grad Graduate School
# 0            4           85             326
# 1            9           85             178
# 2           13           47              99
# 3           10           73             203
# 4           18           63             241
#
# [5 rows x 39 columns]

# %% [markdown]
# ----------

# %% [markdown]
# ## 2. Median household income by zipcode
# - California State, Year 2014
#
# source: http://www.usa.com/rank/california-state--median-household-income--zip-code-rank.htm?yr=9000&dis=&wist=&plow=&phigh=

# %%
# load csv file
income = pd.read_csv('data/median_income_zipcode.csv')

# drop columns Rank and population
income = income.drop(columns = ['Rank', 'Population'])

# rename columns to merge with zip code from the main dfs
income.columns = ['Median Household Income', 'Zip Code']

# transform zip code int to object
income['Zip Code'] = income['Zip Code'].apply(str)

income
# Out:
#      Median Household Income Zip Code
# 0                 236,912.00    94027
# 1                 228,587.00    92145
# 2                 200,325.00    91980
# 3                 187,857.00    94957
# 4                 182,750.00    94022
# ...                      ...      ...
# 1681               11,922.00    93721
# 1682               11,250.00    93530
# 1683               10,625.00    90089
# 1684               10,481.00    95915
# 1685                6,827.00    93669
#
# [1686 rows x 2 columns]

# %%
# Data type
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1686 entries, 0 to 1685
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Median Household Income  1686 non-null   object
#  1   Zip Code                 1686 non-null   object
# dtypes: object(2)
# memory usage: 26.5+ KB

# %%
# Check for missing data
income.isnull().sum()
# Out:
# Median Household Income    0
# Zip Code                   0
# dtype: int64

# %%
# Use string manipulation to remove punctuation 
income['Median Household Income'] = income['Median Household Income'].str.replace('[ \,\-/\(\)\'@]', '')

# convert median houselhold income to int64
income['Median Household Income'] = pd.to_numeric(income['Median Household Income'], errors='coerce').astype(int)

# %% [markdown]
# ### Merge income to df_language and df_math

# %% [markdown]
# **Language Arts & Literature Dataset**

# %%
# Add median household income by merging df_language to income df
df_language_merge = df_language_merge.merge(income, how='left', on='Zip Code')

# Sort values
df_language_merge = df_language_merge.sort_values('School Name', ascending=True)

# Result
df_language_merge.head()
# Out:
#       District Code  School Code  County Name  \
# 8740          66993       129882    Riverside
# 8063          66480      6027767       Orange
# 8119          66522      6028211       Orange
# 8480          73643      6085377       Orange
# 2450          69369      6046114  Santa Clara
#
#                           School Name Zip Code  County Code  Subgroup ID  \
# 8740  21st Century Learning Institute    92223         33.0          1.0
# 8063          A. E. Arnold Elementary    90630         30.0          1.0
# 8119            A. G. Cook Elementary    92844         30.0          1.0
# 8480              A. G. Currie Middle    92780         30.0          1.0
# 2450           A. J. Dorsa Elementary    95122         43.0          1.0
#
#      CAASPP Reported Enrollment Mean Scale Score Percentage Standard Exceeded  \
# 8740                         58              NaN                         8.93
# 8063                        447              NaN                        37.59
# 8119                        192              NaN                        48.39
# 8480                        585              NaN                         6.60
# 2450                        184              NaN                        11.60
#
#       ... Hispanic Pacific Islander White Two/More Races < High School  \
# 8740  ...       33              NaN    18            NaN             6
# 8063  ...      131                *   111              7            15
# 8119  ...       43              NaN    10              6             *
# 8480  ...      532                *    15              *           223
# 2450  ...      166              NaN     *              *            82
#
#      High School Grad Some College College Grad Graduate School  \
# 8740               13           22            9               4
# 8063               44           85          138             121
# 8119               13           14           33               6
# 8480              168           82           39              15
# 2450               55           24           15               *
#
#      Median Household Income
# 8740                 64738.0
# 8063                 84051.0
# 8119                 48345.0
# 8480                 64089.0
# 2450                 57470.0
#
# [5 rows x 40 columns]

# %%
df_language_merge['School Code'].nunique()
# Out:
# 10300

# %%
df_language_merge['School Name'].nunique()
# Out:
# 9042

# %% [markdown]
# **Mathematics Dataset**

# %%
# Add median household income by merging df_math to income df
df_math_merge = df_math_merge.merge(income, how='left', on='Zip Code')

# Sort values
df_math_merge = df_math_merge.sort_values('School Name', ascending=True)

# Result
df_math_merge.head()
# Out:
#       District Code  School Code  County Name  \
# 8740          66993       129882    Riverside
# 8063          66480      6027767       Orange
# 8119          66522      6028211       Orange
# 8480          73643      6085377       Orange
# 2450          69369      6046114  Santa Clara
#
#                           School Name Zip Code  County Code  Subgroup ID  \
# 8740  21st Century Learning Institute    92223         33.0          1.0
# 8063          A. E. Arnold Elementary    90630         30.0          1.0
# 8119            A. G. Cook Elementary    92844         30.0          1.0
# 8480              A. G. Currie Middle    92780         30.0          1.0
# 2450           A. J. Dorsa Elementary    95122         43.0          1.0
#
#      CAASPP Reported Enrollment Mean Scale Score Percentage Standard Exceeded  \
# 8740                         58              NaN                         1.79
# 8063                        447              NaN                        36.36
# 8119                        192              NaN                        46.28
# 8480                        585              NaN                         8.06
# 2450                        184              NaN                        11.05
#
#       ... Hispanic Pacific Islander White Two/More Races < High School  \
# 8740  ...       33              NaN    18            NaN             6
# 8063  ...      131                *   111              7            15
# 8119  ...       43              NaN    10              6             *
# 8480  ...      532                *    15              *           223
# 2450  ...      166              NaN     *              *            82
#
#      High School Grad Some College College Grad Graduate School  \
# 8740               13           22            9               4
# 8063               44           85          138             121
# 8119               13           14           33               6
# 8480              168           82           39              15
# 2450               55           24           15               *
#
#      Median Household Income
# 8740                 64738.0
# 8063                 84051.0
# 8119                 48345.0
# 8480                 64089.0
# 2450                 57470.0
#
# [5 rows x 40 columns]

# %%
df_math_merge['School Code'].nunique()
# Out:
# 10300

# %%
df_math_merge['School Name'].nunique()
# Out:
# 9042

# %% [markdown]
# -----------

# %% [markdown]
# ## 3. Current Expense per Average Daily Attendance
#
# - CA Department of Education 2018-2019.
# - Expenditures for current expense of education, current expense average daily expense per district.
# - EDP 365 = Expenditures for Current Expense of Education
#
# **Average Daily Attendance (ADA):**
# Total ADA is defined as the total days of student attendance divided by the total days of instruction. The type of ADA used is annual district ADA (for the same year as the expenditures) from CDE's "Attendance School District" and "Attendance Charter School" reports and includes ADA from special education programs and applicable charter schools (i.e., those charter schools with data in the district's Current Expense of Education calculation).  ADA credited to districts for the attendance of pupils in county-operated programs is not included.
#
# **Cost Per ADA:**
# By district, the adjusted expenditures are divided by the total ADA to arrive at the Current Expense (or Cost) of Education per ADA.

# %%
expense_df = pd.read_excel('data/currentexpense1819.xlsx')

# drop columns
expense_df = expense_df.drop(columns = ['LEA Type', 'EDP 365'])
expense_df.head(20)
# Out:
#     District Code                        District  Current\nExpense ADA  \
# 0           61119                 Alameda Unified               8968.85
# 1           61127             Albany City Unified               3544.52
# 2           61143                Berkeley Unified               9356.44
# 3           61150           Castro Valley Unified               8940.20
# 4           61168                   Emery Unified                681.82
# 5           61176                 Fremont Unified              33966.73
# 6           61192                 Hayward Unified              18755.20
# 7           61200  Livermore Valley Joint Unified              13142.04
# 8           61218       Mountain House Elementary                 14.93
# 9           61234                  Newark Unified               5552.86
# 10          61242               New Haven Unified              10017.51
# 11          61259                 Oakland Unified              32801.87
# 12          61275           Piedmont City Unified               2521.94
# 13          61291             San Leandro Unified               8472.52
# 14          61309             San Lorenzo Unified               9643.82
# 15          75093                  Dublin Unified              11769.85
# 16          75101              Pleasanton Unified              14502.94
# 17          75119              Sunol Glen Unified                287.16
# 18          61333           Alpine County Unified                 74.47
# 19          73981           Amador County Unified               3775.31
#
#     Current\nExpense Per ADA
# 0               13070.335941
# 1               13150.175366
# 2               17042.573724
# 3               11435.978763
# 4               18339.185137
# 5               11251.288434
# 6               14234.137025
# 7               12069.941505
# 8               32500.253851
# 9               12026.284610
# 10              12396.985164
# 11              16405.572358
# 12              16833.144528
# 13              12590.245804
# 14              13451.415420
# 15              10411.113660
# 16              11402.300655
# 17              12908.355969
# 18              43008.999060
# 19               9560.139141

# %%
expense_df['District'].nunique()
# Out:
# 925

# %% [markdown]
# ### Merge expense_df to df_language_merge and df_math_merge
#
#
# **Language Arts & Literature Dataset**

# %%
# Merge df_language_merge to expense_df
language_expense_df = df_language_merge.merge(expense_df, on='District Code', how='left')

# Sort values
language_expense_df = language_expense_df.sort_values('School Name')

language_expense_df.head()
# Out:
#    District Code  School Code  County Name                      School Name  \
# 0          66993       129882    Riverside  21st Century Learning Institute
# 1          66480      6027767       Orange          A. E. Arnold Elementary
# 2          66522      6028211       Orange            A. G. Cook Elementary
# 3          73643      6085377       Orange              A. G. Currie Middle
# 4          69369      6046114  Santa Clara           A. J. Dorsa Elementary
#
#   Zip Code  County Code  Subgroup ID CAASPP Reported Enrollment  \
# 0    92223         33.0          1.0                         58
# 1    90630         30.0          1.0                        447
# 2    92844         30.0          1.0                        192
# 3    92780         30.0          1.0                        585
# 4    95122         43.0          1.0                        184
#
#   Mean Scale Score Percentage Standard Exceeded  ... Two/More Races  \
# 0              NaN                         8.93  ...            NaN
# 1              NaN                        37.59  ...              7
# 2              NaN                        48.39  ...              6
# 3              NaN                         6.60  ...              *
# 4              NaN                        11.60  ...              *
#
#   < High School High School Grad Some College College Grad Graduate School  \
# 0             6               13           22            9               4
# 1            15               44           85          138             121
# 2             *               13           14           33               6
# 3           223              168           82           39              15
# 4            82               55           24           15               *
#
#   Median Household Income                    District Current\nExpense ADA  \
# 0                 64738.0            Beaumont Unified              9960.32
# 1                 84051.0          Cypress Elementary              3800.49
# 2                 48345.0        Garden Grove Unified             40854.24
# 3                 64089.0              Tustin Unified             22921.38
# 4                 57470.0  Alum Rock Union Elementary              9260.91
#
#   Current\nExpense Per ADA
# 0             11384.420846
# 1             10758.663825
# 2             12964.447700
# 3             10744.324251
# 4             15524.553854
#
# [5 rows x 43 columns]

# %%
language_expense_df['District'].nunique()
# Out:
# 920

# %%
language_expense_df['District Code'].nunique()
# Out:
# 1032

# %% [markdown]
# **Mathematics Dataset**

# %%
# Merge df_math_merge to expense_df
math_expense_df = df_math_merge.merge(expense_df, on='District Code', how='left')

# Sort values
math_expense_df = math_expense_df.sort_values('School Name')

math_expense_df.head()
# Out:
#    District Code  School Code  County Name                      School Name  \
# 0          66993       129882    Riverside  21st Century Learning Institute
# 1          66480      6027767       Orange          A. E. Arnold Elementary
# 2          66522      6028211       Orange            A. G. Cook Elementary
# 3          73643      6085377       Orange              A. G. Currie Middle
# 4          69369      6046114  Santa Clara           A. J. Dorsa Elementary
#
#   Zip Code  County Code  Subgroup ID CAASPP Reported Enrollment  \
# 0    92223         33.0          1.0                         58
# 1    90630         30.0          1.0                        447
# 2    92844         30.0          1.0                        192
# 3    92780         30.0          1.0                        585
# 4    95122         43.0          1.0                        184
#
#   Mean Scale Score Percentage Standard Exceeded  ... Two/More Races  \
# 0              NaN                         1.79  ...            NaN
# 1              NaN                        36.36  ...              7
# 2              NaN                        46.28  ...              6
# 3              NaN                         8.06  ...              *
# 4              NaN                        11.05  ...              *
#
#   < High School High School Grad Some College College Grad Graduate School  \
# 0             6               13           22            9               4
# 1            15               44           85          138             121
# 2             *               13           14           33               6
# 3           223              168           82           39              15
# 4            82               55           24           15               *
#
#   Median Household Income                    District Current\nExpense ADA  \
# 0                 64738.0            Beaumont Unified              9960.32
# 1                 84051.0          Cypress Elementary              3800.49
# 2                 48345.0        Garden Grove Unified             40854.24
# 3                 64089.0              Tustin Unified             22921.38
# 4                 57470.0  Alum Rock Union Elementary              9260.91
#
#   Current\nExpense Per ADA
# 0             11384.420846
# 1             10758.663825
# 2             12964.447700
# 3             10744.324251
# 4             15524.553854
#
# [5 rows x 43 columns]

# %% [markdown]
# ----------

# %% [markdown]
# ## 4. Total Revenue, Total Revenue per Pupil, Total Expenditure per Pupil
#
# - It contains total revenue per school district in California for the academic year 2018-2019.
# - Revenue comes from local, state and federal sources.

# %%
# Load dataset
df_revenue = pd.read_csv('data/ELSI_revenue_details.csv')

# Rename columns
df_revenue.columns = ['Agency Name', 'State', 'District Code', 'Latitude', 'Longitude', 'Total Revenue',
                     'Total Revenue per Pupil', 'Total Expenditures per Pupil']

# Update value in columns
regex_pattern = r'="(.*)"'
regex_group = r'\1'

df_revenue = df_revenue.replace(to_replace=regex_pattern, value=regex_group, regex=True)
df_revenue['District Code'] = df_revenue['District Code'].astype(int)

# drop columns
df_revenue = df_revenue.drop(columns = ['State', 'District Code', 'Total Revenue'])
df_revenue.head()
# Out:
#                 Agency Name   Latitude   Longitude Total Revenue per Pupil  \
# 0               ABC UNIFIED  33.879715 -118.071463                   12922
# 1       ACALANES UNION HIGH  37.905787 -122.099170                   16835
# 2          ACKERMAN CHARTER  38.934997 -121.055904                       †
# 3  ACTON-AGUA DULCE UNIFIED  34.472708 -118.196768                    3811
# 4       ADELANTO ELEMENTARY  34.572373 -117.406551                   12831
#
#   Total Expenditures per Pupil
# 0                        12316
# 1                        15554
# 2                            †
# 3                         3425
# 4                        12322

# %%
# Number of unique agency name
df_revenue['Agency Name'].nunique()
# Out:
# 1139

# %%
# verify data type
df_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Agency Name                   1156 non-null   object
#  1   Latitude                      1156 non-null   float64
#  2   Longitude                     1156 non-null   float64
#  3   Total Revenue per Pupil       1156 non-null   object
#  4   Total Expenditures per Pupil  1156 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 45.3+ KB

# %% [markdown]
# **String manipulation with district name to merge datasets**

# %%
# Use string manipulation to remove punctuation and make column values all caps
# column name District_Name
df_revenue['District_Name'] = df_revenue['Agency Name'].str.replace('[ \.\-/\(\)\'@]', '')
df_revenue['District_Name'] = df_revenue['District_Name'].apply(lambda x: x.upper()).sort_values()
df_revenue.head()
# Out:
#                 Agency Name   Latitude   Longitude Total Revenue per Pupil  \
# 0               ABC UNIFIED  33.879715 -118.071463                   12922
# 1       ACALANES UNION HIGH  37.905787 -122.099170                   16835
# 2          ACKERMAN CHARTER  38.934997 -121.055904                       †
# 3  ACTON-AGUA DULCE UNIFIED  34.472708 -118.196768                    3811
# 4       ADELANTO ELEMENTARY  34.572373 -117.406551                   12831
#
#   Total Expenditures per Pupil          District_Name
# 0                        12316             ABCUNIFIED
# 1                        15554      ACALANESUNIONHIGH
# 2                            †        ACKERMANCHARTER
# 3                         3425  ACTONAGUADULCEUNIFIED
# 4                        12322     ADELANTOELEMENTARY

# %%
# Use string manipulation to remove punctuation and make column values all caps
# column name District_Name
language_expense_df['District_Name'] = language_expense_df['District'].str.replace('[ \.\-/\(\)\'@]', '')

def upperOrNone(x):
    try:
        return x.upper()
    except:
        return "None"

language_expense_df['District_Name'] = language_expense_df['District_Name'].apply(lambda x: upperOrNone(x)).sort_values()

#language_expense_df.head()

# %%
# Use string manipulation to remove punctuation and make column values all caps
# column name District_Name
math_expense_df['District_Name'] = math_expense_df['District'].str.replace('[ \.\-/\(\)\'@]', '')

def upperOrNone(x):
    try:
        return x.upper()
    except:
        return "None"

math_expense_df['District_Name'] = math_expense_df['District_Name'].apply(lambda x: upperOrNone(x)).sort_values()

#math_expense_df

# %% [markdown]
# ### Merge on District_Name
# **Language Arts & Literacy Dataset**

# %%
# Merge language_expense_df to df_revenue
language_revenue_df = language_expense_df.merge(df_revenue, on='District_Name', how='left')

# Sort values
language_revenue_df = language_revenue_df.sort_values('School Name')

# Result
language_revenue_df.head()
# Out:
#    District Code  School Code  County Name                      School Name  \
# 0          66993       129882    Riverside  21st Century Learning Institute
# 1          66480      6027767       Orange          A. E. Arnold Elementary
# 2          66522      6028211       Orange            A. G. Cook Elementary
# 3          73643      6085377       Orange              A. G. Currie Middle
# 4          69369      6046114  Santa Clara           A. J. Dorsa Elementary
#
#   Zip Code  County Code  Subgroup ID CAASPP Reported Enrollment  \
# 0    92223         33.0          1.0                         58
# 1    90630         30.0          1.0                        447
# 2    92844         30.0          1.0                        192
# 3    92780         30.0          1.0                        585
# 4    95122         43.0          1.0                        184
#
#   Mean Scale Score Percentage Standard Exceeded  ... Median Household Income  \
# 0              NaN                         8.93  ...                 64738.0
# 1              NaN                        37.59  ...                 84051.0
# 2              NaN                        48.39  ...                 48345.0
# 3              NaN                         6.60  ...                 64089.0
# 4              NaN                        11.60  ...                 57470.0
#
#                      District Current\nExpense ADA Current\nExpense Per ADA  \
# 0            Beaumont Unified              9960.32             11384.420846
# 1          Cypress Elementary              3800.49             10758.663825
# 2        Garden Grove Unified             40854.24             12964.447700
# 3              Tustin Unified             22921.38             10744.324251
# 4  Alum Rock Union Elementary              9260.91             15524.553854
#
#              District_Name                 Agency Name   Latitude   Longitude  \
# 0          BEAUMONTUNIFIED            BEAUMONT UNIFIED  33.962281 -116.984589
# 1        CYPRESSELEMENTARY          CYPRESS ELEMENTARY  33.824900 -118.045700
# 2       GARDENGROVEUNIFIED        GARDEN GROVE UNIFIED  33.777700 -117.953000
# 3            TUSTINUNIFIED              TUSTIN UNIFIED  33.743100 -117.824900
# 4  ALUMROCKUNIONELEMENTARY  ALUM ROCK UNION ELEMENTARY  37.369388 -121.833560
#
#   Total Revenue per Pupil Total Expenditures per Pupil
# 0                   12626                        14449
# 1                   13641                        11589
# 2                   14695                        16663
# 3                   13166                        12601
# 4                   14788                        15286
#
# [5 rows x 49 columns]

# %% [markdown]
# **Mathematics Dataset**

# %%
# Merge math_expense_df to df_revenue
math_revenue_df = math_expense_df.merge(df_revenue, on='District_Name', how='left')

# Sort values
math_revenue_df = math_revenue_df.sort_values('School Name')

# Result
math_revenue_df.head()
# Out:
#    District Code  School Code  County Name                      School Name  \
# 0          66993       129882    Riverside  21st Century Learning Institute
# 1          66480      6027767       Orange          A. E. Arnold Elementary
# 2          66522      6028211       Orange            A. G. Cook Elementary
# 3          73643      6085377       Orange              A. G. Currie Middle
# 4          69369      6046114  Santa Clara           A. J. Dorsa Elementary
#
#   Zip Code  County Code  Subgroup ID CAASPP Reported Enrollment  \
# 0    92223         33.0          1.0                         58
# 1    90630         30.0          1.0                        447
# 2    92844         30.0          1.0                        192
# 3    92780         30.0          1.0                        585
# 4    95122         43.0          1.0                        184
#
#   Mean Scale Score Percentage Standard Exceeded  ... Median Household Income  \
# 0              NaN                         1.79  ...                 64738.0
# 1              NaN                        36.36  ...                 84051.0
# 2              NaN                        46.28  ...                 48345.0
# 3              NaN                         8.06  ...                 64089.0
# 4              NaN                        11.05  ...                 57470.0
#
#                      District Current\nExpense ADA Current\nExpense Per ADA  \
# 0            Beaumont Unified              9960.32             11384.420846
# 1          Cypress Elementary              3800.49             10758.663825
# 2        Garden Grove Unified             40854.24             12964.447700
# 3              Tustin Unified             22921.38             10744.324251
# 4  Alum Rock Union Elementary              9260.91             15524.553854
#
#              District_Name                 Agency Name   Latitude   Longitude  \
# 0          BEAUMONTUNIFIED            BEAUMONT UNIFIED  33.962281 -116.984589
# 1        CYPRESSELEMENTARY          CYPRESS ELEMENTARY  33.824900 -118.045700
# 2       GARDENGROVEUNIFIED        GARDEN GROVE UNIFIED  33.777700 -117.953000
# 3            TUSTINUNIFIED              TUSTIN UNIFIED  33.743100 -117.824900
# 4  ALUMROCKUNIONELEMENTARY  ALUM ROCK UNION ELEMENTARY  37.369388 -121.833560
#
#   Total Revenue per Pupil Total Expenditures per Pupil
# 0                   12626                        14449
# 1                   13641                        11589
# 2                   14695                        16663
# 3                   13166                        12601
# 4                   14788                        15286
#
# [5 rows x 49 columns]

# %% [markdown]
# ----------

# %% [markdown]
# ## 5. Student Poverty – Free or Reduced Price Meals Data
# - School level data, year 2018-2019
#
#
# source: https://www.cde.ca.gov/ds/sd/sd/fsspfrpm.asp

# %%
freelunch_df = pd.read_excel('data/frpm1819.xlsx')

# Drop columns
freelunch_df = freelunch_df.drop(columns = ['Academic Year', 'County Code', 'District Code',
       'County Name', 'District Name', 'School Name',
       'School Type', 'Educational \nOption Type', 'NSLP \nProvision \nStatus',
       'Charter \nSchool \n(Y/N)', 'Charter \nSchool \nNumber',
       'Charter \nFunding \nType', 'IRC', 'Low Grade', 'High Grade',
       'Percent (%) \nEligible Free \n(K-12)', 'FRPM Count \n(K-12)',
       'Percent (%) \nEligible FRPM \n(K-12)', 'Enrollment \n(Ages 5-17)',
       'Percent (%) \nEligible Free \n(Ages 5-17)', 'FRPM Count \n(Ages 5-17)',
       'Percent (%) \nEligible FRPM \n(Ages 5-17)',
       'CALPADS Fall 1 \nCertification Status', 'Free Meal \nCount \n(Ages 5-17)'])

freelunch_df.head()
# Out:
#    School Code                     District Type  Enrollment \n(K-12)  \
# 0       112607  County Office of Education (COE)                  385
# 1       123968  County Office of Education (COE)                  241
# 2       124172  County Office of Education (COE)                  445
# 3       125567  County Office of Education (COE)                  432
# 4       130401  County Office of Education (COE)                   53
#
#    Free Meal \nCount \n(K-12)
# 0                         262
# 1                         118
# 2                          58
# 3                         113
# 4                          53

# %% [markdown]
# ### Merge on School Code
#
# **Language Arts & Literature Dataset**

# %%
# Merge language_expense_df to df_revenue
language_df = language_revenue_df.merge(freelunch_df, on='School Code', how='left')

# Sort values
language_df = language_df.sort_values('School Name')

# Rename columns
language_df.columns = ['District Code', 'School Code', 'County Name', 'School Name', 'Zip Code', 'County Code',
       'Subgroup ID', 'CAASPP Reported Enrollment', 'Mean Scale Score',
       'Percentage Standard Exceeded', 'Percentage Standard Met',
       'Percentage Standard Met and Above', 'Percentage Standard Nearly Met',
       'Percentage Standard Not Met', 'Students with Scores', 'Male', 'Female',
       'Fluent English','English Learner', 'Ever-Els', 'Migrant',
       'Military', 'Non Military', 'Homeless', 'Non Homeless', 'Disadvantaged',
       'Not Disadvantaged', 'Black', 'Native American', 'Asian', 'Hispanic',
       'Pacific Islander', 'White', 'Two/More Races', '< High School',
       'High School Grad', 'Some College', 'College Grad', 'Graduate School',
       'Median Household Income', 'School_Name', 'District',
       'Current Expense Per ADA', 'District_Name',
       'Agency Name', 'Latitude', 'Longitude',
       'Total Revenue per Pupil', 'Total Expenditures per Pupil',
       'District Type', 'Enrollment K-12', 'Free Meal Count K-12']

# %% [markdown]
# **Mathematics Dataset**

# %%
# Merge language_expense_df to df_revenue
math_df = math_revenue_df.merge(freelunch_df, on='School Code', how='left')

# Sort values
math_df = math_df.sort_values('School Name')

# Rename columns
math_df.columns = ['District Code', 'School Code', 'County Name', 'School Name', 'Zip Code', 'County Code',
       'Subgroup ID', 'CAASPP Reported Enrollment', 'Mean Scale Score',
       'Percentage Standard Exceeded', 'Percentage Standard Met',
       'Percentage Standard Met and Above', 'Percentage Standard Nearly Met',
       'Percentage Standard Not Met', 'Students with Scores', 'Male', 'Female',
       'Fluent English','English Learner', 'Ever-Els', 'Migrant',
       'Military', 'Non Military', 'Homeless', 'Non Homeless', 'Disadvantaged',
       'Not Disadvantaged', 'Black', 'Native American', 'Asian', 'Hispanic',
       'Pacific Islander', 'White', 'Two/More Races', '< High School',
       'High School Grad', 'Some College', 'College Grad', 'Graduate School',
       'Median Household Income', 'School_Name', 'District',
       'Current Expense Per ADA', 'District_Name',
       'Agency Name', 'Latitude', 'Longitude',
       'Total Revenue per Pupil', 'Total Expenditures per Pupil',
       'District Type', 'Enrollment K-12', 'Free Meal Count K-12']

# %% [markdown]
# ## Reorganize columns

# %% [markdown]
# **Language Arts & Literature Dataset**

# %%
# Select columns of interest
df_language = language_df[['School Name', 'School Code', 'Zip Code', 'County Name', 'County Code', 'Latitude', 'Longitude', 
       'Median Household Income', 'CAASPP Reported Enrollment', 'Enrollment K-12',
       'Total Revenue per Pupil', 'Total Expenditures per Pupil', 'Free Meal Count K-12',
       'Current Expense Per ADA', 'Male', 'Female',
       'Fluent English','English Learner', 'Ever-Els', 'Migrant',
       'Military', 'Non Military', 'Homeless', 'Non Homeless', 'Disadvantaged',
       'Not Disadvantaged', 'Black', 'Native American', 'Asian', 'Hispanic',
       'Pacific Islander', 'White', 'Two/More Races', '< High School',
       'High School Grad', 'Some College', 'College Grad', 'Graduate School',
       'Percentage Standard Met and Above']]

df_language.head()
# Out:
#                        School Name  School Code Zip Code  County Name  \
# 0  21st Century Learning Institute       129882    92223    Riverside
# 1          A. E. Arnold Elementary      6027767    90630       Orange
# 2            A. G. Cook Elementary      6028211    92844       Orange
# 3              A. G. Currie Middle      6085377    92780       Orange
# 4           A. J. Dorsa Elementary      6046114    95122  Santa Clara
#
#    County Code   Latitude   Longitude  Median Household Income  \
# 0         33.0  33.962281 -116.984589                  64738.0
# 1         30.0  33.824900 -118.045700                  84051.0
# 2         30.0  33.777700 -117.953000                  48345.0
# 3         30.0  33.743100 -117.824900                  64089.0
# 4         43.0  37.369388 -121.833560                  57470.0
#
#   CAASPP Reported Enrollment  Enrollment K-12  ... Hispanic Pacific Islander  \
# 0                         58             88.0  ...       33              NaN
# 1                        447            739.0  ...      131                *
# 2                        192            366.0  ...       43              NaN
# 3                        585            611.0  ...      532                *
# 4                        184            371.0  ...      166              NaN
#
#    White  Two/More Races < High School High School Grad Some College  \
# 0     18             NaN             6               13           22
# 1    111               7            15               44           85
# 2     10               6             *               13           14
# 3     15               *           223              168           82
# 4      *               *            82               55           24
#
#   College Grad Graduate School Percentage Standard Met and Above
# 0            9               4                             44.64
# 1          138             121                             65.60
# 2           33               6                             81.18
# 3           39              15                             30.38
# 4           15               *                             29.83
#
# [5 rows x 39 columns]

# %%
# create csv file with df_language
#df_language.to_csv("df_language", encoding='utf-8', index=False)

# %% [markdown]
# **Mathematics Dataset**

# %%
df_math = math_df[['School Name', 'School Code', 'Zip Code', 'County Name', 'County Code', 'Latitude', 'Longitude', 
       'Median Household Income', 'CAASPP Reported Enrollment', 'Enrollment K-12',
       'Total Revenue per Pupil', 'Total Expenditures per Pupil', 'Free Meal Count K-12',
       'Current Expense Per ADA', 'Male', 'Female',
       'Fluent English','English Learner', 'Ever-Els', 'Migrant',
       'Military', 'Non Military', 'Homeless', 'Non Homeless', 'Disadvantaged',
       'Not Disadvantaged', 'Black', 'Native American', 'Asian', 'Hispanic',
       'Pacific Islander', 'White', 'Two/More Races', '< High School',
       'High School Grad', 'Some College', 'College Grad', 'Graduate School',
       'Percentage Standard Met and Above']]

df_math.head()
# Out:
#                        School Name  School Code Zip Code  County Name  \
# 0  21st Century Learning Institute       129882    92223    Riverside
# 1          A. E. Arnold Elementary      6027767    90630       Orange
# 2            A. G. Cook Elementary      6028211    92844       Orange
# 3              A. G. Currie Middle      6085377    92780       Orange
# 4           A. J. Dorsa Elementary      6046114    95122  Santa Clara
#
#    County Code   Latitude   Longitude  Median Household Income  \
# 0         33.0  33.962281 -116.984589                  64738.0
# 1         30.0  33.824900 -118.045700                  84051.0
# 2         30.0  33.777700 -117.953000                  48345.0
# 3         30.0  33.743100 -117.824900                  64089.0
# 4         43.0  37.369388 -121.833560                  57470.0
#
#   CAASPP Reported Enrollment  Enrollment K-12  ... Hispanic Pacific Islander  \
# 0                         58             88.0  ...       33              NaN
# 1                        447            739.0  ...      131                *
# 2                        192            366.0  ...       43              NaN
# 3                        585            611.0  ...      532                *
# 4                        184            371.0  ...      166              NaN
#
#    White  Two/More Races < High School High School Grad Some College  \
# 0     18             NaN             6               13           22
# 1    111               7            15               44           85
# 2     10               6             *               13           14
# 3     15               *           223              168           82
# 4      *               *            82               55           24
#
#   College Grad Graduate School Percentage Standard Met and Above
# 0            9               4                             10.71
# 1          138             121                             63.41
# 2           33               6                             71.81
# 3           39              15                             18.35
# 4           15               *                             25.41
#
# [5 rows x 39 columns]

# %%
# create csv file with df_math
#df_math.to_csv("df_math", encoding='utf-8', index=False)

# %% [markdown]
# ----------
